# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#load dataset
df = pd.read_csv("salary_prediction_dataset.csv")

# %%
df.head()
# Out:
#    experience_years  age  education_level  salary
# 0                 8   31                3  211551
# 1                 3   25                1   95628
# 2                 7   36                3  209751
# 3                15   39                1  283745
# 4                16   41                2  328733

# %% [markdown]
# Data clean

# %%
df.shape
# Out:
# (250, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   experience_years  250 non-null    int64
#  1   age               250 non-null    int64
#  2   education_level   250 non-null    int64
#  3   salary            250 non-null    int64
# dtypes: int64(4)
# memory usage: 7.9 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# experience_years    0
# age                 0
# education_level     0
# salary              0
# dtype: int64

# %%
df.describe()
# Out:
#        experience_years         age  education_level         salary
# count         250.00000  250.000000       250.000000     250.000000
# mean            9.68800   35.044000         1.992000  226554.212000
# std             5.99587    6.426763         0.835901   98156.813207
# min             0.00000   22.000000         1.000000   42826.000000
# 25%             4.00000   30.000000         1.000000  133042.250000
# 50%            10.00000   34.000000         2.000000  224808.000000
# 75%            15.00000   41.000000         3.000000  312102.750000
# max            19.00000   48.000000         3.000000  410722.000000

# %% [markdown]
# Vizualization

# %%
df.head(2)
# Out:
#    experience_years  age  education_level  salary
# 0                 8   31                3  211551
# 1                 3   25                1   95628

# %%
#Scatter plot
plt.figure(figsize=(6,4))
sns.scatterplot(data=df, x="experience_years", y="salary", color="green", size=100)
plt.xlabel("Experience Year")
plt.ylabel("Salary")
plt.title("Relation Between Expeience year and Salary")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df, x="age", y="salary", color="green", size=100)
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Relation Between Age and Salary")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df, x="education_level", y="salary", color="green", size=100)
plt.xlabel("Educationa Level")
plt.ylabel("Salary")
plt.title("Relation Between Educationa Level and Salary")
plt.show()

# %%
df.columns
# Out:
# Index(['experience_years', 'age', 'education_level', 'salary'], dtype='object')

# %%
#Paiplot 
sns.pairplot(df[['experience_years', 'age', 'education_level', 'salary']])
plt.show()

# %%
#Boxplot 
plt.figure(figsize=(5,3))
sns.boxplot(x=df['experience_years'])
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.boxplot(df['age'])
plt.show()

# %%
plt.figure(figsize=(3,5))
plt.boxplot(df['education_level'])
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.boxplot(x=df['salary'])
plt.show()

# %%
#Corelation
df.corr()
# Out:
#                   experience_years       age  education_level    salary
# experience_years          1.000000  0.933971        -0.042969  0.982973
# age                       0.933971  1.000000        -0.026847  0.930027
# education_level          -0.042969 -0.026847         1.000000  0.129055
# salary                    0.982973  0.930027         0.129055  1.000000

# %%
plt.figure(figsize=(4,3))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
#Histogram
plt.figure(figsize=(6,3))
plt.hist(df[['experience_years', 'salary']], bins=20)
plt.xlabel('Salary')
plt.ylabel('Experience Year')
plt.show()

# %%
df[['experience_years', 'age', 'education_level', 'salary']].hist(bins=20)
plt.show()

# %%
#feature/Target split
x = df[['experience_years', 'age', 'education_level']]
y = df[['salary']]

# %%
x.head()
# Out:
#    experience_years  age  education_level
# 0                 8   31                3
# 1                 3   25                1
# 2                 7   36                3
# 3                15   39                1
# 4                16   41                2

# %%
y.head()
# Out:
#    salary
# 0  211551
# 1   95628
# 2  209751
# 3  283745
# 4  328733

# %%
#train test split
xtrain, ytrain, xtest, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#      experience_years  age  education_level
# 132                 1   26                3
# 225                12   41                2
# 238                 4   33                1
# 119                18   46                1
# 136                 8   31                3

# %%
ytrain.head()
# Out:
#      experience_years  age  education_level
# 142                 2   25                1
# 6                   2   24                3
# 97                  5   30                1
# 60                  0   27                2
# 112                13   36                2

# %%
xtest.head()
# Out:
#      salary
# 132  108781
# 225  266143
# 238  110963
# 119  344194
# 136  209501

# %%
ytest.head()
# Out:
#      salary
# 142   79295
# 6    113933
# 97   139458
# 60    65803
# 112  287391
