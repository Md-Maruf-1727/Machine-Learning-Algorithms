# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from pandas.api.types import is_numeric_dtype
import pickle

# %%
df = pd.read_csv("subscription_upgrade.csv")

# %%
df.head()
# Out:
#     id   age country device_type  daily_usage_minutes  ads_clicked  \
# 0  1.0  50.0      BD      Tablet                -10.0          5.0
# 1  2.0  35.0     NaN         NaN                  5.0         20.0
# 2  3.0  60.0      US         NaN                 60.0         10.0
# 3  NaN  40.0      PK         NaN                 20.0          2.0
# 4  5.0  50.0      US         NaN                 30.0         10.0
#
#    watch_time  free_features_used  days_since_signup  last_payment_amount  \
# 0    7.743246                 1.0               60.0                  NaN
# 1    1.697019                 8.0              300.0                 50.0
# 2    2.365983                 2.0               60.0                100.0
# 3    9.538726                 1.0                1.0                  0.0
# 4    2.167170                 8.0              300.0                  5.0
#
#    is_active  support_tickets  upgrade
# 0        1.0              NaN      1.0
# 1        NaN             10.0      1.0
# 2        NaN              NaN      1.0
# 3        NaN              NaN      0.0
# 4        NaN             10.0      0.0

# %%
df.shape
# Out:
# (1040, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   988 non-null    float64
#  1   age                  882 non-null    float64
#  2   country              721 non-null    object
#  3   device_type          781 non-null    object
#  4   daily_usage_minutes  872 non-null    float64
#  5   ads_clicked          840 non-null    float64
#  6   watch_time           988 non-null    float64
#  7   free_features_used   850 non-null    float64
#  8   days_since_signup    876 non-null    float64
#  9   last_payment_amount  844 non-null    float64
#  10  is_active            672 non-null    float64
#  11  support_tickets      843 non-null    float64
#  12  upgrade              988 non-null    float64
# dtypes: float64(11), object(2)
# memory usage: 105.8+ KB

# %%
df.describe()
# Out:
#                 id         age  daily_usage_minutes  ads_clicked  watch_time  \
# count   988.000000  882.000000           872.000000   840.000000  988.000000
# mean    500.662955   40.833333            51.267202     6.613095    5.103169
# std     287.458353   15.839809            64.116577     7.097420    2.731126
# min       1.000000   18.000000           -10.000000     0.000000    0.500292
# 25%     253.750000   30.000000             5.000000     1.000000    2.697404
# 50%     500.500000   40.000000            20.000000     5.000000    5.093710
# 75%     745.000000   50.000000            60.000000    10.000000    7.423774
# max    1000.000000   70.000000           200.000000    20.000000    9.995798
#
#        free_features_used  days_since_signup  last_payment_amount   is_active  \
# count          850.000000         876.000000           844.000000  672.000000
# mean             4.741176          68.888128            31.072275    0.513393
# std              3.273742          98.464398            35.300012    0.500193
# min              1.000000          -5.000000             0.000000    0.000000
# 25%              2.000000           5.000000             5.000000    0.000000
# 50%              3.000000          30.000000            10.000000    1.000000
# 75%              8.000000         120.000000            50.000000    1.000000
# max             10.000000         300.000000           100.000000    1.000000
#
#        support_tickets     upgrade
# count       843.000000  988.000000
# mean          3.525504    0.502024
# std           3.692806    0.500249
# min           0.000000    0.000000
# 25%           1.000000    0.000000
# 50%           2.000000    1.000000
# 75%           5.000000    1.000000
# max          10.000000    1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(11)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# id                      52
# age                    158
# country                319
# device_type            257
# daily_usage_minutes    166
# ads_clicked            198
# watch_time              52
# free_features_used     190
# days_since_signup      163
# last_payment_amount    196
# is_active              364
# support_tickets        195
# upgrade                 52
# dtype: int64

# %%
df = df.drop(['is_active'], axis=1)

# %%
df.columns
# Out:
# Index(['id', 'age', 'country', 'device_type', 'daily_usage_minutes',
#        'ads_clicked', 'watch_time', 'free_features_used', 'days_since_signup',
#        'last_payment_amount', 'support_tickets', 'upgrade'],
#       dtype='object')

# %%
#visualisation
plt.figure(figsize=(4,3))
sns.boxplot(df['age'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['daily_usage_minutes'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['ads_clicked'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['watch_time'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['free_features_used'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['days_since_signup'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['last_payment_amount'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['support_tickets'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='age', y='upgrade', data=df)
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='daily_usage_minutes', y='upgrade', data=df)
plt.show()

# %%
plt.figure(figsize=(4,3))
df['country'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(4,3))
df['country'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(4,3))
df['device_type'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(4,3))
df['upgrade'].value_counts().plot(kind='bar')
plt.show()

# %%
#boxplot for removing outlier
def oulier(df, col):
    q1 = df[col].quantile(.25)
    q3 = df[col].quantile(.75)

    iqr = q3 - q1

    lower_wh = q1 - 1.5 * iqr
    upper_wh = q3 + 1.5 * iqr

    return df[(df[col] >= lower_wh) & (df[col] <= upper_wh)]

# %%
num_col = ['daily_usage_minutes', 'days_since_signup']

# %%
df_clean = df.copy()

# %%
for col2 in num_col:
    df_clean = oulier(df_clean, col2)

# %%
df = df_clean.copy()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['daily_usage_minutes'])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(df['days_since_signup'])
plt.show()

# %%
df.shape
# Out:
# (567, 12)

# %%
df.isna().sum()
# Out:
# id                      30
# age                     85
# country                187
# device_type            138
# daily_usage_minutes      0
# ads_clicked            108
# watch_time              26
# free_features_used     111
# days_since_signup        0
# last_payment_amount    100
# support_tickets        113
# upgrade                 28
# dtype: int64

# %%
df = df.drop(['id'], axis=1)

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df['country'] = df['country'].ffill()

# %%
df['device_type'] = df['device_type'].ffill()

# %%
df['ads_clicked'] = df['ads_clicked'].fillna(df['ads_clicked'].mean())

# %%
df['watch_time'] = df['watch_time'].fillna(df['watch_time'].mean())

# %%
df['free_features_used'] = df['free_features_used'].fillna(df['free_features_used'].mean())

# %%
df['last_payment_amount'] = df['last_payment_amount'].fillna(df['last_payment_amount'].mean())

# %%
df['support_tickets'] = df['support_tickets'].fillna(df['support_tickets'].mean())

# %%
df.isna().sum()
# Out:
# age                     0
# country                 0
# device_type             0
# daily_usage_minutes     0
# ads_clicked             0
# watch_time              0
# free_features_used      0
# days_since_signup       0
# last_payment_amount     0
# support_tickets         0
# upgrade                28
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# age                    0
# country                0
# device_type            0
# daily_usage_minutes    0
# ads_clicked            0
# watch_time             0
# free_features_used     0
# days_since_signup      0
# last_payment_amount    0
# support_tickets        0
# upgrade                0
# dtype: int64

# %%
df.shape
# Out:
# (539, 11)

# %%
df = df.reset_index(drop=True)

# %%
#encoding
le = LabelEncoder()
mms = MinMaxScaler()

# %%
df['country'] = le.fit_transform(df['country'])

# %%
df['device_type'] = le.fit_transform(df['device_type'])

# %%
df.columns
# Out:
# Index(['age', 'country', 'device_type', 'daily_usage_minutes', 'ads_clicked',
#        'watch_time', 'free_features_used', 'days_since_signup',
#        'last_payment_amount', 'support_tickets', 'upgrade'],
#       dtype='object')

# %%
#Feature / Target split
x = df[['age', 'country', 'device_type', 'daily_usage_minutes', 'ads_clicked',
       'watch_time', 'free_features_used', 'days_since_signup',
       'last_payment_amount', 'support_tickets']]
y = df[['upgrade']]

# %%
#encoding 
#for col in x.columns:
#    if is_numeric_dtype(x[col]):
#        x[col] = mms.fit_transform(x[[col]])
#    else:
#        x[col] = le.fit_transform(x[col])

# %%
x.head()
# Out:
#     age  country  device_type  daily_usage_minutes  ads_clicked  watch_time  \
# 0  50.0        0            1                -10.0          5.0    7.743246
# 1  60.0        4            1                 60.0         10.0    2.365983
# 2  40.0        2            1                 20.0          2.0    9.538726
# 3  50.0        4            3                 20.0          0.0    5.151432
# 4  60.0        3            1                 10.0         20.0    6.625080
#
#    free_features_used  days_since_signup  last_payment_amount  support_tickets
# 0                 1.0               60.0            31.948608         3.378855
# 1                 2.0               60.0           100.000000         3.378855
# 2                 1.0                1.0             0.000000         3.378855
# 3                 5.0               30.0             5.000000         5.000000
# 4                 2.0               -5.0            31.948608         3.378855

# %%
#train test split 
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
xtrain.head()
# Out:
#            age  country  device_type  daily_usage_minutes  ads_clicked  \
# 461  25.000000        2            0                 60.0          1.0
# 231  25.000000        3            1                  5.0          1.0
# 446  25.000000        0            0                 60.0          2.0
# 449  40.000000        0            1                 60.0          1.0
# 448  41.782158        0            0                 30.0          5.0
#
#      watch_time  free_features_used  days_since_signup  last_payment_amount  \
# 461    3.899207            4.730263               10.0                  0.0
# 231    7.510534            4.730263                5.0                  0.0
# 446    8.092001            2.000000               10.0                100.0
# 449    5.994418            5.000000                1.0                  5.0
# 448    7.443268            1.000000              120.0                100.0
#
#      support_tickets
# 461         3.378855
# 231         3.378855
# 446         0.000000
# 449         3.378855
# 448         1.000000

# %%
ytrain.head()
# Out:
#      upgrade
# 461      1.0
# 231      0.0
# 446      0.0
# 449      1.0
# 448      1.0

# %%
#model implentation
knn = KNeighborsClassifier()

# %%
model = knn.fit(xtrain, ytrain)
# Out:
# c:\Users\MD Maruf\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
model.score(xtrain, ytrain)
# Out:
# 0.6867749419953596

# %%
model.score(xtest, ytest)
# Out:
# 0.5370370370370371

# %%
#prediction
pred_y = model.predict(xtest)

# %%
#confission metrics
cm = confusion_matrix(ytest, pred_y)
cm
# Out:
# array([[29, 23],
#        [27, 29]])

# %%
plt.figure(figsize=(4,3))
sns.heatmap(cm, annot=True)
plt.show()

# %%
#classification report
cl = classification_report(ytest, pred_y)
print(cl)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.56      0.54        52
#          1.0       0.56      0.52      0.54        56
#
#     accuracy                           0.54       108
#    macro avg       0.54      0.54      0.54       108
# weighted avg       0.54      0.54      0.54       108

# %%
#accuracy score
asc = accuracy_score(ytest, pred_y)
asc
# Out:
# 0.5370370370370371

# %%
#saving model 
pickle.dump(model, open('subscription.pkl', 'wb'))
