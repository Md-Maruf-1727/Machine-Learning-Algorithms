# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.api.types import is_numeric_dtype
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
import imblearn
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score, roc_curve, f1_score, auc

# %%
df = pd.read_csv("Bank_Transaction_Risk_Dataset.csv")

# %%
df.head()
# Out:
#    Transaction_Amount  Account_Balance  Customer_Tenure_Months  \
# 0             5993.43          3684.99                      42
# 1             4723.47         35809.54                     115
# 2             6295.38          5628.33                      78
# 3             8046.06          7777.62                      10
# 4             4531.69          9775.65                     111
#
#    Daily_Transaction_Count  Transaction_Hour  Failed_Login_Attempts  \
# 0                        3                19                      1
# 1                        3                 9                      0
# 2                        6                22                      0
# 3                        5                 8                      0
# 4                        2                 1                      0
#
#   Transaction_Type Merchant_Category Device_Type Country Account_Type  \
# 0         transfer          gambling      mobile      IN      savings
# 1         Cash_Out          gambling      mobile      IN      current
# 2         transfer          gambling      mobile      IN      current
# 3         cash_out            travel     desktop   india      savings
# 4         TRANSFER          GAMBLING     desktop      BD     business
#
#    KYC_Status High_Risk_Transaction
# 0  unverified                    No
# 1    verified                    No
# 2   Verified                     No
# 3    verified                    No
# 4   Verified                     No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Transaction_Amount       790 non-null    float64
#  1   Account_Balance          790 non-null    float64
#  2   Customer_Tenure_Months   800 non-null    int64
#  3   Daily_Transaction_Count  800 non-null    int64
#  4   Transaction_Hour         800 non-null    int64
#  5   Failed_Login_Attempts    800 non-null    int64
#  6   Transaction_Type         790 non-null    object
#  7   Merchant_Category        800 non-null    object
#  8   Device_Type              790 non-null    object
#  9   Country                  800 non-null    object
#  10  Account_Type             800 non-null    object
#  11  KYC_Status               800 non-null    object
#  12  High_Risk_Transaction    800 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 81.4+ KB

# %%
#seeing duplicate value
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#seeing NAN value
df.isna().sum()
# Out:
# Transaction_Amount         10
# Account_Balance            10
# Customer_Tenure_Months      0
# Daily_Transaction_Count     0
# Transaction_Hour            0
# Failed_Login_Attempts       0
# Transaction_Type           10
# Merchant_Category           0
# Device_Type                10
# Country                     0
# Account_Type                0
# KYC_Status                  0
# High_Risk_Transaction       0
# dtype: int64

# %%
df['Transaction_Amount'] = df['Transaction_Amount'].fillna(df['Transaction_Amount'].mean())

# %%
df['Account_Balance'] = df['Account_Balance'].fillna(df['Account_Balance'].mean())

# %%
df['Transaction_Type'] = df['Transaction_Type'].ffill()

# %%
df['Device_Type'] = df['Device_Type'].bfill()

# %%
le = LabelEncoder()
mms = MinMaxScaler()

# %%
for col in df.columns:
    if is_numeric_dtype(df[col]):
        df[col] = mms.fit_transform(df[[col]])
    else:
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Transaction_Amount  Account_Balance  Customer_Tenure_Months  \
# 0            0.096349         0.104552                0.347458
# 1            0.079982         0.295720                0.966102
# 2            0.100241         0.116117                0.652542
# 3            0.122804         0.128907                0.076271
# 4            0.077511         0.140797                0.932203
#
#    Daily_Transaction_Count  Transaction_Hour  Failed_Login_Attempts  \
# 0                      0.3          0.826087                   0.25
# 1                      0.3          0.391304                   0.00
# 2                      0.6          0.956522                   0.00
# 3                      0.5          0.347826                   0.00
# 4                      0.2          0.043478                   0.00
#
#    Transaction_Type  Merchant_Category  Device_Type  Country  Account_Type  \
# 0                 4                  3            2        2             2
# 1                 0                  3            2        2             1
# 2                 4                  3            2        2             1
# 3                 3                  4            1        3             2
# 4                 1                  0            1        0             0
#
#    KYC_Status  High_Risk_Transaction
# 0           1                      0
# 1           2                      0
# 2           0                      0
# 3           2                      0
# 4           0                      0

# %%
for col2 in df.columns:
    print(col2)
    plt.figure(figsize=(2,1))
    sns.boxplot(df[col2])
    plt.show()
# Out:
# Transaction_Amount
# Account_Balance
# Customer_Tenure_Months
# Daily_Transaction_Count
# Transaction_Hour
# Failed_Login_Attempts
# Transaction_Type
# Merchant_Category
# Device_Type
# Country
# Account_Type
# KYC_Status
# High_Risk_Transaction

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
plt.show()

# %%
df[['High_Risk_Transaction']].shape
# Out:
# (800, 1)

# %%
#feature and target split
x = df.drop(['High_Risk_Transaction'], axis=1)
y = df[['High_Risk_Transaction']]

# %%
y.value_counts()
# Out:
# High_Risk_Transaction
# 0                        699
# 1                        101
# Name: count, dtype: int64

# %%
#random over sampler
ros = RandomOverSampler()

# %%
new_x, new_y = ros.fit_resample(x,y)
new_x.shape, new_y.shape
# Out:
# ((1398, 12), (1398, 1))

# %%
new_y.value_counts()
# Out:
# High_Risk_Transaction
# 0                        699
# 1                        699
# Name: count, dtype: int64

# %%
xtrain, xtest, ytrain, ytest = train_test_split(new_x, new_y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#       Transaction_Amount  Account_Balance  Customer_Tenure_Months  \
# 48              0.092403         0.228360                0.398305
# 155             0.065133         0.259729                0.500000
# 756             0.096262         0.155998                0.135593
# 1070            0.134189         0.208122                0.093220
# 303             0.099279         0.034647                0.398305
#
#       Daily_Transaction_Count  Transaction_Hour  Failed_Login_Attempts  \
# 48                        0.3          0.173913                   0.00
# 155                       0.2          0.608696                   0.25
# 756                       0.2          0.434783                   0.00
# 1070                      0.0          0.826087                   0.00
# 303                       0.2          0.304348                   0.00
#
#       Transaction_Type  Merchant_Category  Device_Type  Country  Account_Type  \
# 48                   1                  4            2        0             2
# 155                  2                  4            1        2             1
# 756                  3                  3            1        0             0
# 1070                 3                  0            0        2             2
# 303                  1                  2            2        2             0
#
#       KYC_Status
# 48             0
# 155            1
# 756            2
# 1070           1
# 303            1

# %%
ytrain.head()
# Out:
#       High_Risk_Transaction
# 48                        0
# 155                       1
# 756                       0
# 1070                      1
# 303                       1

# %%
dect = DecisionTreeClassifier()

# %%
model = dect.fit(xtrain, ytrain)

# %%
model.score(xtrain, ytrain)
# Out:
# 1.0

# %%
model.score(xtest, ytest)
# Out:
# 0.9392857142857143

# %%
#prediction
pred = model.predict(xtest)

# %%
#confussion metrix
cm = confusion_matrix(ytest, pred)
cm
# Out:
# array([[123,  17],
#        [  0, 140]])

# %%
plt.figure(figsize=(3,2))
sns.heatmap(cm, annot=True,cmap='coolwarm',annot_kws={'size':10,'color':'indigo'})
# Out:
# <Axes: >

# %%
#classification report
cl = classification_report(ytest, pred)
print(cl)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94       140
#            1       0.89      1.00      0.94       140
#
#     accuracy                           0.94       280
#    macro avg       0.95      0.94      0.94       280
# weighted avg       0.95      0.94      0.94       280

# %%
#accurac score
acc = accuracy_score(ytest, pred)
acc
# Out:
# 0.9392857142857143

# %%
#f1 score
f1 = f1_score(ytest, pred)
f1
# Out:
# 0.9427609427609428

# %%
#rur auc score
ras = roc_auc_score(ytest, pred)
ras
# Out:
# 0.9392857142857143

# %%
#roc curve
fpr, tpr, thresholds = roc_curve(ytest, pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='black', label = f'ROC curv (area = {roc_auc:.2f})')
plt.plot([0,1],[0,1], color='green', linestyle='--', label = 'Random Guessing (area = 0.5)')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR) or Sensitivity')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 15))
plot_tree(model, feature_names=x.columns, filled=True, rounded=True)
plt.show()
