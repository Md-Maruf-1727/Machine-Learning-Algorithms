# %%
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.tag import pos_tag
from nltk.stem import PorterStemmer, WordNetLemmatizer
import spacy
from sklearn.feature_extraction.text import CountVectorizer

# %%
from wordcloud import WordCloud

# %%
#nltk.download('punkt')

# %%
#nltk.download('punkt_tab')

# %%
#nltk.download('stopwords')

# %%
#nltk.download('averaged_perceptron_tagger_eng')

# %%
sent = "Natural Language Processing (NLP) is a field of artificial intelligence that helps computers understand human language."

# %%
word = word_tokenize(sent)

# %%
part = pos_tag(word)
part
# Out:
# [('Natural', 'JJ'),
#  ('Language', 'NNP'),
#  ('Processing', 'NNP'),
#  ('(', '('),
#  ('NLP', 'NNP'),
#  (')', ')'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('field', 'NN'),
#  ('of', 'IN'),
#  ('artificial', 'JJ'),
#  ('intelligence', 'NN'),
#  ('that', 'WDT'),
#  ('helps', 'VBZ'),
#  ('computers', 'NNS'),
#  ('understand', 'VBP'),
#  ('human', 'JJ'),
#  ('language', 'NN'),
#  ('.', '.')]

# %%
for ind, words in enumerate(word):
    print(f'{ind}: {words}')
# Out:
# 0: Natural
# 1: Language
# 2: Processing
# 3: (
# 4: NLP
# 5: )
# 6: is
# 7: a
# 8: field
# 9: of
# 10: artificial
# 11: intelligence
# 12: that
# 13: helps
# 14: computers
# 15: understand
# 16: human
# 17: language
# 18: .

# %%
para = "Natural Language Processing is fun. It helps computers understand human language. People use NLP in chatbots. It is also useful for sentiment analysis. Many companies use NLP to improve their products. Learning NLP opens new opportunities."

# %%
sent_tok = sent_tokenize(para)
sent_tok
# Out:
# ['Natural Language Processing is fun.',
#  'It helps computers understand human language.',
#  'People use NLP in chatbots.',
#  'It is also useful for sentiment analysis.',
#  'Many companies use NLP to improve their products.',
#  'Learning NLP opens new opportunities.']

# %%
for indx, senten in enumerate(sent_tok):
    print(f'{indx}: {senten}')
# Out:
# 0: Natural Language Processing is fun.
# 1: It helps computers understand human language.
# 2: People use NLP in chatbots.
# 3: It is also useful for sentiment analysis.
# 4: Many companies use NLP to improve their products.
# 5: Learning NLP opens new opportunities.

# %%
st_word = stopwords.words('english')
st_word
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
new_sent = "Hello, My name is maruf. And I am 20 years old."
word = word_tokenize(new_sent)
sent_t = sent_tokenize(new_sent)
pos = pos_tag(word)
print(word)
print(sent_t)
print(pos)
# Out:
# ['Hello', ',', 'My', 'name', 'is', 'maruf', '.', 'And', 'I', 'am', '20', 'years', 'old', '.']
# ['Hello, My name is maruf.', 'And I am 20 years old.']
# [('Hello', 'NNP'), (',', ','), ('My', 'NNP'), ('name', 'NN'), ('is', 'VBZ'), ('maruf', 'VBN'), ('.', '.'), ('And', 'CC'), ('I', 'PRP'), ('am', 'VBP'), ('20', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('.', '.')]

# %%
port_st = PorterStemmer()
sentnce = "Natural Language Processing (NLP) is a field of artificial intelligence that helps computers understand human language."
sentnce_token = word_tokenize(sentnce)
stem_word = [port_st.stem(word2) for word2 in sentnce_token]
insen = " ".join(stem_word)
insen
# Out:
# 'natur languag process ( nlp ) is a field of artifici intellig that help comput understand human languag .'

# %%
new_sentence = "Natural Language Processing is fun. It helps computers understand human language. People use NLP in chatbots. It is also useful for sentiment analysis. Many companies use NLP to improve their products. Learning NLP opens new opportunities."
new_sentence_port_st = PorterStemmer()
new_sentence_token = word_tokenize(new_sentence)
for new_sentence_stem in new_sentence_token:
    new_sentence_token_stemmer = new_sentence_port_st.stem(new_sentence_stem)
    print(f'{new_sentence_stem} --> {new_sentence_token_stemmer}')
# Out:
# Natural --> natur
# Language --> languag
# Processing --> process
# is --> is
# fun --> fun
# . --> .
# It --> it
# helps --> help
# computers --> comput
# understand --> understand
# human --> human
# language --> languag
# . --> .
# People --> peopl
# use --> use
# NLP --> nlp
# in --> in
# chatbots --> chatbot
# . --> .
# It --> it
# is --> is
# also --> also
# useful --> use
# for --> for
# sentiment --> sentiment
# analysis --> analysi
# . --> .
# Many --> mani
# companies --> compani
# use --> use
# NLP --> nlp
# to --> to
# improve --> improv
# their --> their
# products --> product
# . --> .
# Learning --> learn
# NLP --> nlp
# opens --> open
# new --> new
# opportunities --> opportun
# . --> .

# %%
#nltk.download('wordnet')

# %%
wnl_sen = "Natural Language Processing is fun. It helps computers understand human language. People use NLP in chatbots. It is also useful for sentiment analysis. Many companies use NLP to improve their products. Learning NLP opens new opportunities."
wnl = WordNetLemmatizer()
wnl_sen_token = word_tokenize(wnl_sen)
lem_word = [wnl.lemmatize(wnl_sen_token_lem) for wnl_sen_token_lem in wnl_sen_token]
join_lem_word = " ".join(lem_word)
join_lem_word
# Out:
# 'Natural Language Processing is fun . It help computer understand human language . People use NLP in chatbots . It is also useful for sentiment analysis . Many company use NLP to improve their product . Learning NLP open new opportunity .'

# %%
wnl_sen_new = "Natural Language Processing is fun. It helps computers understand human language. People use NLP in chatbots. It is also useful for sentiment analysis. Many companies use NLP to improve their products. Learning NLP opens new opportunities."
wnl_sen_new_token = word_tokenize(wnl_sen_new)
for wnl_sen_new_lem in wnl_sen_new_token:
    wnl_sen_new_token_lematize = wnl.lemmatize(wnl_sen_new_lem)
    print(f'{wnl_sen_new_lem} --> {wnl_sen_new_token_lematize}')
# Out:
# Natural --> Natural
# Language --> Language
# Processing --> Processing
# is --> is
# fun --> fun
# . --> .
# It --> It
# helps --> help
# computers --> computer
# understand --> understand
# human --> human
# language --> language
# . --> .
# People --> People
# use --> use
# NLP --> NLP
# in --> in
# chatbots --> chatbots
# . --> .
# It --> It
# is --> is
# also --> also
# useful --> useful
# for --> for
# sentiment --> sentiment
# analysis --> analysis
# . --> .
# Many --> Many
# companies --> company
# use --> use
# NLP --> NLP
# to --> to
# improve --> improve
# their --> their
# products --> product
# . --> .
# Learning --> Learning
# NLP --> NLP
# opens --> open
# new --> new
# opportunities --> opportunity
# . --> .

# %%
spacy_sen = "Natural Language Processing is fun. It helps computers understand human language. People use NLP in chatbots. It is also useful for sentiment analysis. Many companies use NLP to improve their products. Learning NLP opens new opportunities."

# %%
nlp = spacy.load("en_core_web_sm")

# %%
spacy_lema_token = nlp(spacy_sen)
spacy_word_lema = [spacy_word.lemma_ for spacy_word in spacy_lema_token]
spacy_word_j = " ".join(spacy_word_lema)
spacy_word_j
# Out:
# 'Natural Language processing be fun . it help computer understand human language . People use NLP in chatbot . it be also useful for sentiment analysis . many company use NLP to improve their product . learn NLP open new opportunity .'

# %%
type(spacy_lema_token)
# Out:
# spacy.tokens.doc.Doc

# %%
new_spacy_sen = "Natural Language Processing is fun. It helps computers understand human language. People use NLP in chatbots. It is also useful for sentiment analysis. Many companies use NLP to improve their products. Learning NLP opens new opportunities."

new_spacy_token = nlp(new_spacy_sen)
for new_spacy_word in new_spacy_token:
    new_spacy_lema = new_spacy_word.lemma_
    print(f'{new_spacy_word} --> {new_spacy_lema}')
# Out:
# Natural --> Natural
# Language --> Language
# Processing --> processing
# is --> be
# fun --> fun
# . --> .
# It --> it
# helps --> help
# computers --> computer
# understand --> understand
# human --> human
# language --> language
# . --> .
# People --> People
# use --> use
# NLP --> NLP
# in --> in
# chatbots --> chatbot
# . --> .
# It --> it
# is --> be
# also --> also
# useful --> useful
# for --> for
# sentiment --> sentiment
# analysis --> analysis
# . --> .
# Many --> many
# companies --> company
# use --> use
# NLP --> NLP
# to --> to
# improve --> improve
# their --> their
# products --> product
# . --> .
# Learning --> learn
# NLP --> NLP
# opens --> open
# new --> new
# opportunities --> opportunity
# . --> .

# %%
a = ["change", "changes", "changed", "changing"]
stem_a = [port_st.stem(a_s) for a_s in a]
stem_a
# Out:
# ['chang', 'chang', 'chang', 'chang']

# %%
b = ["change", "changes", "changed", "changing"]
lema_b = [wnl.lemmatize(b_s) for b_s in b]
lema_b
# Out:
# ['change', 'change', 'changed', 'changing']

# %%
new_sent_for_l = ent = "Natural Language Pro54cessing (NLP) is a field of artificial intelligence that helps computers und3erstande humans language."

new_sent_token = word_tokenize(new_sent_for_l)
stop_remove = [new_sent_tokens.lower() for new_sent_tokens in new_sent_token if new_sent_tokens not in st_word]
new_sent_lema = [wnl.lemmatize(stop_removes) for stop_removes in stop_remove]
new_sent_lema_join = " ".join(new_sent_lema)
new_sent_lema_join
import re
clean_pun =re.sub(r"[^\w\s]", "", new_sent_lema_join).strip()
clean_num= re.sub(r"\d+", "", clean_pun)
clean_num
# Out:
# 'natural language processing  nlp  field artificial intelligence help computer understande human language'

# %%
countVect = CountVectorizer()
transform_data = countVect.fit_transform([clean_num])
transform_data
data_toarray = transform_data.toarray()
data_toarray.shape
# Out:
# (1, 11)

# %%
def create_cloud(string, title= None):
    cloud = WordCloud(
    width=400,
    height=200,
    background_color='white',
    min_font_size=10,
    max_words=100,
    ).generate(string)

    # 3. Plot the WordCloud image
    plt.figure(figsize=(10, 5)) # Set figure size
    plt.imshow(cloud, interpolation='bilinear') # Display the image smoothly
    plt.axis("off") # Hide axes
    plt.title("My Awesome Word Cloud") # Add a title
    plt.show()

# %%
create_cloud((clean_num), "wordcloud for negative sentence")
